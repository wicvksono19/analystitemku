# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Caller and Agent Data.xls')

# %%
df.dtypes
# Out:
# Date               datetime64[ns]
# Time (Local)                int64
# Eyeballs                    int64
# Zeroes                      int64
# Completed Calls             int64
# Requests                    int64
# Unique Agents               int64
# dtype: object

# %%
df['Date'].ffill(inplace=True)

# %%
df.set_index('Date', inplace= True)

# %%
df
# Out:
#             Time (Local)  Eyeballs   Zeroes   Completed Calls  Requests   \
# Date
# 2012-09-10             7          5        0                2          2
# 2012-09-10             8          6        0                2          2
# 2012-09-10             9          8        3                0          0
# 2012-09-10            10          9        2                0          1
# 2012-09-10            11         11        1                4          4
# ...                  ...        ...      ...              ...        ...
# 2012-09-24             2          3        3                0          2
# 2012-09-24             3          3        3                0          1
# 2012-09-24             4          1        1                0          0
# 2012-09-24             5          4        2                1          1
# 2012-09-24             6          9        1                2          2
#
#             Unique Agents
# Date
# 2012-09-10              9
# ...

# %%
df['CD'] = df.groupby('Date')['Completed Calls'].cumsum()
# Out:
#             Time (Local)  Eyeballs   Zeroes   Completed Calls  Requests   \
# Date
# 2012-09-10             7          5        0                2          2
# 2012-09-10             8          6        0                2          2
# 2012-09-10             9          8        3                0          0
# 2012-09-10            10          9        2                0          1
# 2012-09-10            11         11        1                4          4
# ...                  ...        ...      ...              ...        ...
# 2012-09-24             2          3        3                0          2
# 2012-09-24             3          3        3                0          1
# 2012-09-24             4          1        1                0          0
# 2012-09-24             5          4        2                1          1
# 2012-09-24             6          9        1                2          2
#
#             Unique Agents  CD
# Date
# 2012-09-10              9   2
# ...

# %%
plt.figure(figsize=(16,10))
plt.bar(df.index.to_list(),df['CD'])
plt.xticks(df.index.to_list())
plt.xticks(rotation=45)
plt.show()

# %%
df.rename(columns={'Time (Local)':'Time'}, inplace=True)
df
# Out:
#             Time  Eyeballs   Zeroes   Completed Calls  Requests   \
# Date
# 2012-09-10     7          5        0                2          2
# 2012-09-10     8          6        0                2          2
# 2012-09-10     9          8        3                0          0
# 2012-09-10    10          9        2                0          1
# 2012-09-10    11         11        1                4          4
# ...          ...        ...      ...              ...        ...
# 2012-09-24     2          3        3                0          2
# 2012-09-24     3          3        3                0          1
# 2012-09-24     4          1        1                0          0
# 2012-09-24     5          4        2                1          1
# 2012-09-24     6          9        1                2          2
#
#             Unique Agents  CD
# Date
# 2012-09-10              9   2
# 2012-09-10             14   4
# 2012-09-10             14   4
# 2012-09-10             14   4
# ...

# %%
df.rename(columns={'Requests ':'Requests'}, inplace=True)
df
# Out:
#             Time  Eyeballs   Zeroes   Completed Calls  Requests  \
# Date
# 2012-09-10     7          5        0                2         2
# 2012-09-10     8          6        0                2         2
# 2012-09-10     9          8        3                0         0
# 2012-09-10    10          9        2                0         1
# 2012-09-10    11         11        1                4         4
# ...          ...        ...      ...              ...       ...
# 2012-09-24     2          3        3                0         2
# 2012-09-24     3          3        3                0         1
# 2012-09-24     4          1        1                0         0
# 2012-09-24     5          4        2                1         1
# 2012-09-24     6          9        1                2         2
#
#             Unique Agents  CD
# Date
# 2012-09-10              9   2
# 2012-09-10             14   4
# 2012-09-10             14   4
# 2012-09-10             14   4
# ...

# %%
df['TR'] = df.groupby('Time')['Requests'].cumsum()

# %%
plt.figure(figsize=(16,10))
plt.bar(df['Time'],df['TR'])
plt.xticks(df['Time'])
plt.xticks(rotation=45)
plt.show()

# %%
df.columns
# Out:
# Index(['Time', 'Eyeballs ', 'Zeroes ', 'Completed Calls', 'Requests',
#        'Unique Agents', 'CD', 'TR'],
#       dtype='object')

# %%
df.rename(columns={'Unique Agents':'Unique'}, inplace=True)
df
# Out:
#             Time  Eyeballs   Zeroes   Completed Calls  Requests  Unique  CD  \
# Date
# 2012-09-10     7          5        0                2         2       9   2
# 2012-09-10     8          6        0                2         2      14   4
# 2012-09-10     9          8        3                0         0      14   4
# 2012-09-10    10          9        2                0         1      14   4
# 2012-09-10    11         11        1                4         4      11   8
# ...          ...        ...      ...              ...       ...     ...  ..
# 2012-09-24     2          3        3                0         2       0   1
# 2012-09-24     3          3        3                0         1       0   1
# 2012-09-24     4          1        1                0         0       0   1
# 2012-09-24     5          4        2                1         1       3   2
# 2012-09-24     6          9        1                2         2       7   4
#
#              TR
# Date
# 2012-09-10    2
# ...

# %%
df['TU'] = df.groupby('Time')['Unique'].cumsum()

# %%
plt.figure(figsize=(16,10))
plt.bar(df['Time'],df['TU'])
plt.xticks(df['Time'])
plt.xticks(rotation=45)
plt.show()

# %%
df.rename(columns={'Zeroes ':'Zeroes'}, inplace=True)

# %%
df['DZ'] = df.groupby('Date')['Zeroes'].cumsum()

# %%
plt.figure(figsize=(16,10))
plt.bar(df.index.to_list(),df['DZ'])
plt.xticks(df.index.to_list())
plt.xticks(rotation=45)
plt.show()

# %%
df.rename(columns={'Eyeballs ':'Eyeballs'}, inplace=True)

# %%
df['TE'] = df.groupby('Time')['Eyeballs'].cumsum()

# %%
plt.figure(figsize=(16,10))
plt.bar(df.Time,df['Eyeballs'])
plt.xticks(df.Time)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(16,10))
plt.bar(df.Time,df['Unique'])
plt.xticks(df.Time)
plt.xticks(rotation=45)
plt.show()
